# %%
x = int(input('Digite um valor no intervalo de -100 até 100: '))
while (x < 99) and (x > -99):
    x = int(input('Digite um valor no intervalo de -100 até 100: '))
print('Encerrado')
# Out:
# Encerrado
