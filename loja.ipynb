# %%
#EXIGÊNCIA 1 DE 6 - Mensagem de boas Vindas com nome e Sobrenome.
print('Bem-vindo a Loja do Vitor Eduardo Blocki') 
#EXIGÊNCIA 2 DE 6 - Implementar input de valor unitário e da quantidade do produto.
valor_produto = float(input('Insira o valor do produto:'))
quantidade_produto = float(input('Insira a quantidade do produto:'))

valor_total = valor_produto * quantidade_produto

#EXIGÊNCIA 5 DE 6 - Implementar as estruturas if, elif e else.
#EXIGÊNCIA 3 DE 6 - Implementar descontos conforme enunciado
if valor_total >= 2500 and valor_total < 6000:
    valor_total_novo = valor_total - valor_total * 0.4 #A mutiplicação é feita por 0.4 para que haja o valor descontado para confecção da conta matemática
    #EXIGÊNCIA 4 DE 6 - Implementar valor com e sem desconto.
    print(f'Parabéns, você ganhou um desconto de 4%, o valor a ser pago seria de R${valor_total}, como desconto será de R${valor_total_novo}')
elif valor_total >= 6000 and valor_total < 10000:
    valor_total_novo = valor_total - valor_total * 0.11
    print(f'Parabéns, você ganhou um desconto de 7%, o valor a ser pago seria de R${valor_total}, como desconto será de R${valor_total_novo}')
elif valor_total >= 10000:
    valor_total_novo = valor_total - valor_total * 0.11
    print(f'Parabéns, você ganhou um desconto de 11%, o valor a ser pago seria de R${valor_total}, como desconto será de R${valor_total_novo}')
else: 
    print(f'O valor total está abaixo de R$2500, você não receberá desconto, logo o valor a pagar será de R${valor_total}') 

#EXIGÊNCIA 6 DE 6 - Inserir comentários relevante no código
# Out:
# Bem-vindo a Loja do Vitor Eduardo Blocki
# Parabéns, você ganhou um desconto de 4%, o valor a ser pago seria de R$3000.0, como desconto será de R$1800.0
